# %%
import numpy as np
from calciumscripts import *

# %%
""" Plot and calculate DF/F0 etc for 2p data from a local injection of Ribo-jGCaMP8s
    processed in suite2p. """

# Location of suite2p output data.
datadir = "data/loc_ribo8s/"
name = "loc_ribo8s"
figname = datadir + name

# Load suite2p .npy output.
F = np.load(datadir + "F.npy", allow_pickle=True)
Fneu = np.load(datadir + "Fneu.npy", allow_pickle=True)
iscell = np.load(datadir + "iscell.npy", allow_pickle=True)

# Range of cells to plot for calciumplot over time plotmin, plotmax (seconds * acquisitionrate)
cellrange = [4, 15, 16, 24, 32]
plotmin, plotmax = int(40 * 30.9), int(140 * 30.9)

# Plot cells in cellrange over time plotmin to plotmax.
calciumplot(plotmin=plotmin, plotmax=plotmax, cellrange=cellrange, figname=figname, F=F, Fneu=Fneu, iscell=iscell)

# Calculate DF/F0 etc for up to 80 cells if cellrange=False.
#somaoverneuropil(cellrange=False, F=F, Fneu=Fneu, iscell=iscell, figname=figname)

# Live plot of calcium traces for browsing data.
# calciumplotlive(cellrange=[4, 15, 16, 24, 32], F=F, Fneu=Fneu, iscell=iscell)

# %%
""" Local injection of Soma-jGCaMP8s """

# Location of suite2p output data.
datadir = "data/loc_soma8s_kkl281/"
name = "loc_soma8s"
figname = datadir + name

# Load suite2p .npy output.
F = np.load(datadir + 'F.npy', allow_pickle=True)
Fneu = np.load(datadir + 'Fneu.npy', allow_pickle=True)
iscell = np.load(datadir + 'iscell.npy', allow_pickle=True)

# Range of cells to plot for calciumplot over time plotmin, plotmax (seconds * acquisitionrate)
cellrange = [4,10,22,24,25]
plotmin, plotmax = int(14*30.9), int(114*30.9)

calciumplot(plotmin=plotmin, plotmax=plotmax, cellrange=cellrange, figname=figname, F=F, Fneu=Fneu, iscell=iscell)
#somaoverneuropil(cellrange=False, F=F, Fneu=Fneu, iscell=iscell, figname=figname)
#calciumplotlive(cellrange=cellrange, F=F, Fneu=Fneu, iscell=iscell)

# %%
""" RO injection of jGCaMP8s """
datadir = "data/roi_norm8s/"
name = "roi_norm8s"
figname = datadir + name

F = np.load(datadir + 'F.npy', allow_pickle=True)
Fneu = np.load(datadir + 'Fneu.npy', allow_pickle=True)
iscell = np.load(datadir + 'iscell.npy', allow_pickle=True)

cellrange = [2, 4, 8, 16, 17]
plotmin, plotmax = int(14*30.9), int(114*30.9)

calciumplot(plotmin=plotmin, plotmax=plotmax, cellrange=cellrange, figname=figname, F=F, Fneu=Fneu, iscell=iscell)
#somaoverneuropil(cellrange=False, F=F, Fneu=Fneu, iscell=iscell, figname=figname)
#calciumplotlive(cellrange=list(range(38)), F=F, Fneu=Fneu, iscell=iscell)

# %%
""" RO injection of Soma-jGCaMP8m, elongated trace for an extended figure. """
datadir = "data/roi_soma8m/"
name = "roi_soma8m"
figname = datadir + name

F = np.load(datadir + 'F.npy', allow_pickle=True)
Fneu = np.load(datadir + 'Fneu.npy', allow_pickle=True)
iscell = np.load(datadir + 'iscell.npy', allow_pickle=True)

cellrange = [2,3,6,11,23]
plotmin, plotmax = int(14*30.9), int(250.8*30.9)

calciumplot(plotmin=plotmin, plotmax=plotmax, cellrange=cellrange, figname=figname, F=F, Fneu=Fneu, iscell=iscell, size=(17.6,6))
#somaoverneuropil(cellrange=False, F=F, Fneu=Fneu, iscell=iscell, figname=figname)
#calciumplotlive(cellrange=list(range(30)), F=F, Fneu=Fneu, iscell=iscell)

# %%
""" Local injection of  RiboL1-jGCaMP8s """
datadir = "data/loc_l1rb8s_(copy)/"
name = "loc_l1rb8s"
figname = datadir + name

F = np.load(datadir + 'F.npy', allow_pickle=True)
Fneu = np.load(datadir + 'Fneu.npy', allow_pickle=True)
iscell = np.load(datadir + 'iscell.npy', allow_pickle=True)

cellrange = [0,1,2,5,16]
plotmin, plotmax = int(14*30.9), int(114*30.9)

calciumplot(plotmin=plotmin, plotmax=plotmax, cellrange=cellrange, figname=figname, F=F, Fneu=Fneu, iscell=iscell)
#somaoverneuropil(cellrange=False, F=F, Fneu=Fneu, iscell=iscell, figname=figname)
#calciumplotlive(cellrange=list(range(40)), F=F, Fneu=Fneu, iscell=iscell)

# %%
""" Local injection Ribo8sL1-GCaMP8s, Axon-jRex-GECO """

# Location of suite2p output data.
datadir = "data/loc_L1rb8s_336/"
name = "loc_L1rb8s_336"
figname = datadir + name

# Load suite2p .npy output.
F = np.load(datadir + "F.npy", allow_pickle=True)
Fneu = np.load(datadir + "Fneu.npy", allow_pickle=True)
iscell = np.load(datadir + "iscell.npy", allow_pickle=True)

# Load Axon-jREX-GECO data.
F_axon = np.load(datadir + "F_axons2.npy", allow_pickle=True)
Fneu_axon = np.load(datadir + "Fneu_axons2.npy", allow_pickle=True)
stats = np.load(datadir + "stat.npy", allow_pickle=True)  # for roistotext
ops = np.load(datadir + "ops.npy", allow_pickle=True).item()  # for roistotext

# Range of cells to plot for calciumplot over time plotmin, plotmax (seconds * acquisitionrate)
cellrange = [7, 9, 3, 20, 4]
plotmin, plotmax = int(40 * 30.9), int(140 * 30.9)

#calciumplot(plotmin=plotmin, plotmax=plotmax, cellrange=cellrange, figname=figname, F=F, Fneu=Fneu, iscell=iscell)

# Plot somatic and axonal calcium sensor pairs overlaid, each pair is defined as [soma, axon, filter]
# is the level of gaussian filter applied to the noisy axonal signal.
#calciumplotaxon(plotmin=plotmin, cell_axon_pair=[[7, 711, 1], [7, 2124, 3]], plotmax=plotmax, figname=figname+"1", F=F, Fneu=Fneu, iscell=iscell, F_axons=F_axon, Fneu_axons=Fneu_axon, offsetnbr=500)
calciumplotaxon(plotmin=18000, cell_axon_pair=[[7, 711, 1], [7, 2124, 3]], plotmax=20000, figname=figname+"2", F=F, Fneu=Fneu, iscell=iscell, F_axons=F_axon, Fneu_axons=Fneu_axon, offsetnbr=500)
calciumplotaxon(plotmin=8000, cell_axon_pair=[[42, 842, 2], [42, 930, 2], [42, 1651, 2], [42, 1186, 2], [42, 1345, 2]], plotmax=10000, figname=figname+"3", F=F, Fneu=Fneu, iscell=iscell, F_axons=F_axon, Fneu_axons=Fneu_axon, offsetnbr=650)
# somaoverneuropil(cellrange=False, F=F, Fneu=Fneu, iscell=iscell, figname=figname)
# calciumplotlive(cellrange=list(range(100)), F=F, Fneu=Fneu, iscell=iscell)
# roistotext(stats=stats, ops=ops, iscell=iscell, outputdir=datadir)
